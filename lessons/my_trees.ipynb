# %% [markdown]
# My Python Code for EDA

# %%
import pandas as pd

# %%
x = pd.read_csv("trees.csv")

# %%
x.head(5)
# Out:
#    Girth  Height  Volume Zone
# 0    8.3      70    10.3    B
# 1    8.6      65    10.3    A
# 2    8.8      63    10.2    A
# 3   10.5      72    16.4    A
# 4   10.7      81    18.8    B

# %%
x.shape
# Out:
# (31, 4)

# %%
x['Girth'].mean()
# Out:
# np.float64(13.248387096774195)

# %%
x['Girth'].std()
# Out:
# 3.1381386168387504

# %%
x['Volume'].mean()
# Out:
# np.float64(30.17096774193548)

# %%
x['Volume'].std()
# Out:
# 16.43784644346469

# %%
zoneA = x.loc[x['Zone'] == 'A']
zoneB = x.loc[x['Zone'] == 'B']

# %%
zoneA['Volume'].mean()
# Out:
# np.float64(28.585714285714282)

# %%
zoneB['Volume'].mean()
# Out:
# np.float64(33.5)

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(x['Girth'])
plt.xlabel("Girth")
# Out:
# Text(0.5, 0, 'Girth')

# %%
plt.plot(x['Girth'], x['Volume'],'o', color = 'green')
plt.xlabel("Girth")
plt.ylabel("Volume")
# Out:
# Text(0, 0.5, 'Volume')

# %%
plt.plot(x['Height'], x['Volume'],'o', color = 'blue')
plt.xlabel("Height")
plt.ylabel("Volume")
# Out:
# Text(0, 0.5, 'Volume')

# %%
plt.plot(x['Girth'], x['Height'],'o', color = 'red')
plt.xlabel("Girth")
plt.ylabel("Height")
# Out:
# Text(0, 0.5, 'Height')

# %%
import numpy as np

# %%
np.corrcoef(x['Girth'], x['Volume'])
# Out:
# array([[1.        , 0.96711937],
#        [0.96711937, 1.        ]])

# %%
np.corrcoef(x['Height'], x['Volume'])
# Out:
# array([[1.        , 0.59824965],
#        [0.59824965, 1.        ]])

# %%
np.corrcoef(x['Girth'], x['Height'])
# Out:
# array([[1.        , 0.51928007],
#        [0.51928007, 1.        ]])

# %%
pd.plotting.scatter_matrix(x, marker ='o')
# Out:
# array([[<Axes: xlabel='Girth', ylabel='Girth'>,
#         <Axes: xlabel='Height', ylabel='Girth'>,
#         <Axes: xlabel='Volume', ylabel='Girth'>],
#        [<Axes: xlabel='Girth', ylabel='Height'>,
#         <Axes: xlabel='Height', ylabel='Height'>,
#         <Axes: xlabel='Volume', ylabel='Height'>],
#        [<Axes: xlabel='Girth', ylabel='Volume'>,
#         <Axes: xlabel='Height', ylabel='Volume'>,
#         <Axes: xlabel='Volume', ylabel='Volume'>]], dtype=object)

# %%
print(x)
# Out:
#     Girth  Height  Volume Zone
# 0     8.3      70    10.3    B
# 1     8.6      65    10.3    A
# 2     8.8      63    10.2    A
# 3    10.5      72    16.4    A
# 4    10.7      81    18.8    B
# 5    10.8      83    19.7    A
# 6    11.0      66    15.6    A
# 7    11.0      75    18.2    A
# 8    11.1      80    22.6    A
# 9    11.2      75    19.9    B
# 10   11.3      79    24.2    A
# 11   11.4      76    21.0    A
# 12   11.4      76    21.4    B
# 13   11.7      69    21.3    A
# 14   12.0      75    19.1    A
# 15   12.9      74    22.2    A
# 16   12.9      85    33.8    A
# 17   13.3      86    27.4    A
# 18   13.7      71    25.7    B
# 19   13.8      64    24.9    B
# 20   14.0      78    34.5    B
# 21   14.2      80    31.7    A
# 22   14.5      74    36.3    A
# 23   16.0      72    38.3    A
# 24   16.3      77    42.6    A
# 25   17.3      81    55.4    A
# 26   17.5      82    55.7    A
# 27   17.9      80    58.3    A
# 28   18.0      80    51.5    B
# 29   18.0      80    51.0    B
# 30   20.6      87    77.0    B

# %%
def in2m(z):
  return z*0.0254

# %%
x['Girth_m'] = x['Girth'].apply(in2m)

# %%
x.head()
# Out:
#    Girth  Height  Volume Zone  Girth_m
# 0    8.3      70    10.3    B  0.21082
# 1    8.6      65    10.3    A  0.21844
# 2    8.8      63    10.2    A  0.22352
# 3   10.5      72    16.4    A  0.26670
# 4   10.7      81    18.8    B  0.27178
